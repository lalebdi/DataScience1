# %%
import numpy as np

# %%
lending_co = np.loadtxt("Lending-company-numeric.csv", delimiter = ',')
lending_co
# Out:
# array([[ 2000.,    40.,   365.,  3121.,  4241., 13621.],
#        [ 2000.,    40.,   365.,  3061.,  4171., 15041.],
#        [ 1000.,    40.,   365.,  2160.,  3280., 15340.],
#        ...,
#        [ 2000.,    40.,   365.,  4201.,  5001., 16600.],
#        [ 1000.,    40.,   365.,  2080.,  3320., 15600.],
#        [ 2000.,    40.,   365.,  4601.,  4601., 16600.]])

# %%
np.argwhere(lending_co)
# Out:
# array([[   0,    0],
#        [   0,    1],
#        [   0,    2],
#        ...,
#        [1042,    3],
#        [1042,    4],
#        [1042,    5]])

# %%
np.argwhere(lending_co == False) # only 2 zeros in the set
# Out:
# array([[116,   4],
#        [430,   3]])

# %%
np.argwhere(lending_co < 100)
# Out:
# array([[   0,    1],
#        [   1,    1],
#        [   2,    1],
#        ...,
#        [1040,    1],
#        [1041,    1],
#        [1042,    1]])

# %%
lending_nan = np.genfromtxt("Lending-company-Numeric-NAN.csv", delimiter = ";")
lending_nan
# Out:
# array([[ 2000.,    40.,   365.,  3121.,  4241., 13621.],
#        [ 2000.,    40.,   365.,  3061.,  4171., 15041.],
#        [ 1000.,    40.,   365.,  2160.,  3280., 15340.],
#        ...,
#        [   nan,    40.,   365.,  4201.,  5001., 16600.],
#        [ 1000.,    40.,   365.,  2080.,  3320., 15600.],
#        [ 2000.,    40.,   365.,  4601.,  4601., 16600.]])

# %%
np.isnan(lending_nan).sum()
# Out:
# 260

# %%
np.argwhere(np.isnan(lending_nan))
# Out:
# array([[  11,    3],
#        [  15,    3],
#        [  27,    3],
#        [  58,    3],
#        [  60,    4],
#        [  85,    4],
#        [ 117,    5],
#        [ 152,    1],
#        [ 152,    2],
#        [ 152,    4],
#        [ 172,    1],
#        [ 175,    1],
#        [ 175,    2],
#        [ 176,    3],
#        [ 177,    4],
#        [ 178,    5],
#        [ 211,    3],
#        [ 229,    0],
#        [ 230,    1],
#        [ 237,    1],
#        [ 247,    3],
#        [ 251,    5],
#        [ 252,    4],
#        [ 258,    1],
#        [ 260,    3],
#        [ 262,    4],
#        [ 271,    5],
#        [ 272,    4],
#        [ 284,    2],
#        [ 284,    3],
#        [ 297,    1],
#        [ 297,    2],
#        [ 300,    3],
#        [ 315,    3],
#        [ 315,    5],
#        [ 327,    4],
#        [ 336,    4],
#        [ 343,    0],
#        [ 344,    2],
#        [ 346,    2],
#        [ 363,    3],
#        [ 375,    3],
#        [ 377,    2],
# ...

# %%
for array_index in np.argwhere(np.isnan(lending_nan)):
    lending_nan[array_index[0], array_index[1]]  = 0

# %%
np.isnan(lending_nan).sum()
# Out:
# 0
