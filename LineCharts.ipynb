# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df_spx_ftse = pd.read_csv("line_chart_data.csv")
df_spx_ftse
# Out:
#             Date   GSPC500   FTSE100
# 0       1/3/2000  0.003264  0.000000
# 1       1/4/2000 -0.009549  0.000000
# 2       1/5/2000 -0.038345 -0.038137
# 3       1/6/2000  0.001922 -0.019502
# 4       1/7/2000  0.000956 -0.013571
# ...          ...       ...       ...
# 2865  12/27/2010 -0.002282  0.002135
# 2866  12/28/2010  0.003539  0.000000
# 2867  12/29/2010 -0.000254  0.000000
# 2868  12/30/2010  0.000524 -0.002080
# 2869  12/31/2010 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
df_spx_ftse["new_date"] = pd.to_datetime(df_spx_ftse["Date"])

# %%
df_spx_ftse["new_date"]
# Out:
# 0      2000-01-03
# 1      2000-01-04
# 2      2000-01-05
# 3      2000-01-06
# 4      2000-01-07
#           ...
# 2865   2010-12-27
# 2866   2010-12-28
# 2867   2010-12-29
# 2868   2010-12-30
# 2869   2010-12-31
# Name: new_date, Length: 2870, dtype: datetime64[ns]

# %%
labels = ["S&P", "FTSE"]
plt.figure(figsize =(20, 8))
plt.plot(df_spx_ftse["new_date"], df_spx_ftse["GSPC500"])
plt.plot(df_spx_ftse["new_date"], df_spx_ftse["FTSE100"])
plt.title("Stocks", fontsize = 14, fontweight = "bold")
plt.xlabel('Returns')
plt.ylabel("Date")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# %%
df_spx_ftse_h2 = df_spx_ftse[(df_spx_ftse.new_date >= '2008-07-01') & (df_spx_ftse.new_date <= '2008-12-31')]
df_spx_ftse_h2
# Out:
#             Date   GSPC500   FTSE100   new_date
# 2216    7/1/2008 -0.001072  0.017360 2008-07-01
# 2217    7/2/2008  0.007151 -0.025951 2008-07-02
# 2218    7/3/2008 -0.017779 -0.009781 2008-07-03
# 2219    7/4/2008  0.000000  0.009270 2008-07-04
# 2220    7/7/2008 -0.000047 -0.011650 2008-07-07
# ...          ...       ...       ...        ...
# 2343  12/25/2008  0.000000  0.000000 2008-12-25
# 2344  12/26/2008  0.006529  0.000000 2008-12-26
# 2345  12/29/2008  0.003289  0.000000 2008-12-29
# 2346  12/30/2008 -0.002052  0.024380 2008-12-30
# 2347  12/31/2008  0.022985  0.026578 2008-12-31
#
# [132 rows x 4 columns]

# %%
labels = ["S&P", "FTSE"]
plt.figure(figsize =(20, 8))
plt.plot(df_spx_ftse_h2["new_date"], df_spx_ftse_h2["GSPC500"], color = "midnightblue")
plt.plot(df_spx_ftse_h2["new_date"], df_spx_ftse_h2["FTSE100"], color = "crimson")
plt.title("Stocks", fontsize = 14, fontweight = "bold")
plt.xlabel('Returns')
plt.ylabel("Date")
plt.legend(labels = labels, fontsize = "large")
plt.show()
