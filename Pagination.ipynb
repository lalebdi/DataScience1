# %%
import requests
import pandas as pd
import json

# %%
base_site = "https://jobs.github.com/positions.json"

# %%
r = requests.get(base_site, params={"description": "data science", "location": "New York"})
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# [{'id': '21d9e0e2-9b9a-4c7d-8c0c-26871b0bb7a6',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/21d9e0e2-9b9a-4c7d-8c0c-26871b0bb7a6',
#   'created_at': 'Thu Apr 01 19:07:46 UTC 2021',
#   'company': 'Thorlabs',
#   'company_url': 'https://www.thorlabs.com/',
#   'location': '07860',
#   'title': 'Mid-Level SQL Server Data Engineer',
#   'description': '<p>Looking for an experienced dynamic SQL Server Database Administrator/Engineer, with deep knowledge and broad experience of MS SQL and Azure Cloud skills to join our Database Engineering team at Thorlabs. We are a fast-paced and growing group that manages the complete data needs of the firm. Primary role of this position will be to cover all aspects of data needs in the organization, production system support and troubleshooting, implementing database systems, setup database monitoring, implement Disaster recovery Strategies, project planning, developing documentation and runbooks. This person will be part of a group rotation providing weekend on-call support.</p>\n<p>Essential Job Functions include the following, but are not limited to:</p>\n<ul>\n<li>Conduct monitoring, maintenance and development of our database solutions on-prem and Azure; including business critical reporting and BI systems.</li>\n<li>Troubleshoot technical issues and identify modifications needed in existing applications to meet changing user requirements. Research and troubleshoot data pipeline questions.</li>\n<li>Manage and maintain optimal performance of business critical applications, including Dynamics AX.</li>\n<li>Manage security role, Role base access, authentication and authorization of users accessing various database systems.</li>\n<li>Would require understanding manufacturing and lean processes to execute some functional specifications</li>\n<li>Develop and implement Disaster Recovery (DR) strategies, high availability and backup restore schedules.</li>\n<li>Develop and optimize queries to increase efficiency in our systems</li>\n<li>Collaborate on problem resolution, team decisions and project planning.</li>\n<li>Build fail-proof data pipelines (ETL) to move data between different systems while maintaining integrity using Azure tools and cloud-based ETL development processes.</li>\n<li>Experience connecting to varied data sources, on-prem and cloud.</li>\n<li>Excellent SQL coding experience with performance optimization for data queries.</li>\n<li>Understands different data models like normalized, de-normalized, stars, and snowflake models. Working experience with transactional, temporal, time series, and structured and unstructured data, AzureDataLake is a plus.</li>\n<li>Working experience with MPP DWH system like Azure synapse is highly desirable.</li>\n<li>Experience in deployment and maintenance of ETL Jobs.</li>\n<li>Is familiar with the reporting tools like Power Bi and SSRS or any other.</li>\n</ul>\n<p>Qualifications</p>\n<p>Experience:</p>\n<ul>\n<li>5+ years’ experience</li>\n</ul>\n<p>Education:</p>\n<ul>\n<li>Bachelor’s degree in Engineering/Science, or equivalent work experience</li>\n</ul>\n<p>Specialized Knowledge and Skills:</p>\n<ul>\n<li>SQL: clustering, mirroring, replication, scripting, stored procedures, functions, performance tuning and trouble shooting.</li>\n<li>Azure: Azure Data Factory, Azure SQL database, Azure Synapse, Databricks, Azure Analysis Services, Azure DataLake storage</li>\n<li>Reporting Tools: Power Bi, SSRS</li>\n<li>Languages: TSQL, Python, PowerShell, JSON, Pyspark</li>\n<li>Data modelling: Tabular model, Star Schema, Columnar modelling</li>\n</ul>\n<p>Thorlabs values its diverse environment and is proud to be an Equal Employment Opportunity/Affirmative Action Employer. All qualified individuals will receive consideration for employment without regard to race, color, religion, gender, gender identity or expression, sexual orientation, national origin, genetics, disability, age or veteran status. Job descriptions are not intended as and do not create employment contracts. The organization maintains its status as an at-will employer. Employees can be terminated for any reason not prohibited by law.</p>\n',
#   'how_to_apply': '<p>Please  be sure to complete an application on the Company\'s career site for consideration. Direct link below:</p>\n<p><a href="https://recruiting.myapps.paychex.com/appone/MainInfoReq.asp?R_ID=3392010">https://recruiting.myapps.paychex.com/appone/MainInfoReq.asp?R_ID=3392010</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBb1NmIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--3c8771d67e8b937cccead21303ae98dfa0f14420/Company%20Logo.jpg'},
#  {'id': '353b2b8f-55c6-44b2-976e-2089c9503e22',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/353b2b8f-55c6-44b2-976e-2089c9503e22',
#   'created_at': 'Thu Apr 01 18:54:05 UTC 2021',
#   'company': 'Thorlabs',
#   'company_url': 'https://www.thorlabs.com/',
#   'location': '07860',
#   'title': 'Enterprise Data Architect',
#   'description': '<p>The Enterprise Data Architect (EDA) primary goal is to keep data easily accessible and accurate. To meet that goal, the EDA reviews, refines and implements data standards. Examples of data standards include those that define how data is categorized or how codes are assigned to represent specific products, customers and other data types. Gathering information about data use in the workplace, the architect creates a blueprint or road map, showing processes and services that affect data use and data standards. The architect works with project managers and business stakeholders to implement that design.</p>\n<p>The EDA is further expected to act as the team leader for the global DBA resources and provide them daily technical guidance and management. The role as EDA is hands on, relishing learning, provide guidance and create value added services for a data hungry organization\nAlthough the location of the position is in Newton, NJ, from time to time it may be required to undertake duties at other ThorLabs locations.</p>\n<p>Essential Job Functions include the following, but are not limited to:</p>\n<ul>\n<li>The EDA works with teams to solve business data problems.</li>\n<li>The EDA develops data modeling methods, databases, data warehouses, data lakes, master data and metadata.</li>\n<li>The EDA acts as a data evangelist to address business process improvement with users in finance, purchasing, quality, human resources and other departments.\nIn addition to the essential functions and duties listed above, all positions are also responsible for:</li>\n<li>Meeting company standards pertaining to quantity and quality of work performed on an ongoing basis, performing all work related tasks in a manner that is in compliance with all Company policies and procedures.</li>\n<li>Adhering to Company policies, procedures, and directives regarding standards of workplace behavior in completing job duties and assignments.</li>\n</ul>\n<p>The Company retains the right to change or assign other duties to this position.</p>\n<p>Physical Activities:</p>\n<ul>\n<li>This is largely a sedentary role; however, some filing is required. This would require the ability to lift files, open filing cabinets and bend or stand as necessary.</li>\n</ul>\n<p>Experience:</p>\n<ul>\n<li>10+ years of experience in database design, data warehousing and data modeling</li>\n</ul>\n<p>Education:</p>\n<ul>\n<li>Bachelor’s degree in Engineering/Science, or equivalent work experience.</li>\n</ul>\n<p>Specialized Knowledge and Skills:</p>\n<ul>\n<li>Prior experience as DBA architect</li>\n<li>Experience with the MS SQL stack - SSIS, SSAS, SSRS, Azure Synapse, Azure Analysis Services etc.</li>\n<li>Knowledge of ERP system databases, preferable MS Dynamics/Axapta.</li>\n<li>Comes from a mixed heterogeneous SQL environment</li>\n<li>Knowledge of project management</li>\n<li>Experience with data modeling software</li>\n<li>Experience with migrating to cloud, preferably Azure</li>\n<li>Communicate directly with users, speaking in terms they understand</li>\n<li>Should have good business knowledge and be able to explain technical concepts without using complex, technical terms.</li>\n</ul>\n<p>Thorlabs values its diverse environment and is proud to be an Equal Employment Opportunity/Affirmative Action employer. All qualified individuals will receive consideration for employment without regard to race, color, religion, gender, gender identify or expression, sexual orientation, national origin, genetics, disability, age or veteran status. Job descriptions are not intended as and do not create employment contracts. The organization maintains its status as an at-will employer. Employees can be terminated for any reason not prohibited by law.</p>\n',
#   'how_to_apply': '<p>Please be sure to complete an application on the Company\'s career site for consideration. Direct link below:</p>\n<p><a href="https://recruiting.myapps.paychex.com/appone/MainInfoReq.asp?R_ID=3429023">https://recruiting.myapps.paychex.com/appone/MainInfoReq.asp?R_ID=3429023</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBb0dmIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--28374c4e5671b119cc2a94db42e38ceca515a16b/Company%20Logo.jpg'}]

# %%
len(r.json())
# Out:
# 2

# %%
r = requests.get(base_site)
r.status_code
# Out:
# 200

# %%
len(r.json())
# Out:
# 50

# %%
r = requests.get(base_site, params = {"page": 2})
r.ok
# Out:
# True

# %%
len(r.json())
# Out:
# 50

# %%
r = requests.get(base_site, params = {"page": 5})
r.status_code
len(r.json())
# Out:
# 26

# %%
results = []

# %%
for i in range(5):
    r= requests.get(base_site, params ={"page": i+1})
    if len(r.json()) == 0:
        break
    else:
        results.extend(r.json())

# %%
results
# Out:
# [{'id': '10a3bd7a-f93a-4d20-94b0-d65c6fcaecd4',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/10a3bd7a-f93a-4d20-94b0-d65c6fcaecd4',
#   'created_at': 'Mon Apr 26 16:44:07 UTC 2021',
#   'company': 'SuprNation Ltd',
#   'company_url': 'https://www.suprnation.com',
#   'location': 'Remote',
#   'title': 'Senior Backend Developer',
#   'description': '<p>SuprNation is looking for a backend developer to join our development team at our Malta office. The ideal candidate should have the following qualities:</p>\n<ul>\n<li>Is able to work autonomously – Freedom with Responsibility is the mantra at the SuprNation office!</li>\n<li>Is passionate about coding and loves to learn and share new concepts and techniques.</li>\n<li>Can work in a flat organisation where ideas (rather than people) ‘win’ at the end of the day.</li>\n<li>Can write functional code and understands the benefits of immutability. A sea of immutability with islands of mutability. Odersky! rings a bell? Great!</li>\n<li>Gets excited upon hearing about Event Sourcing, Microservices, CQRS and Actors! If you know who - Eric Evans and Carl Hewitt are you will feel right at home!</li>\n<li>Is not fixated with a particular language/technology but rather with the underlying concepts and ideas.</li>\n<li>Is eager to collaborate with other crazy smart people to create an amazing casino product.</li>\n</ul>\n',
#   'how_to_apply': '<p>Email your resume at <a href="mailto:mark@suprnation.com">mark@suprnation.com</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBaFNpIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--9361a2de34573cd800bdad0e96188952bdfa094c/250558695426_b1e9850bc60befc8c138_132.png'},
#  {'id': '98b06bf7-df44-4c18-937f-bbb68116398b',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/98b06bf7-df44-4c18-937f-bbb68116398b',
#   'created_at': 'Mon Apr 26 16:03:55 UTC 2021',
#   'company': 'lawpilots GmbH',
#   'company_url': 'https://www.lawpilots.com/de-de/',
#   'location': 'Berlin',
#   'title': 'Software Developer (Backend / Infrastructure) (m/w/d)',
#   'description': '<p><strong>Intro</strong></p>\n<p>Join us in Berlin</p>\n<p>At lawpilots, we create digital learning that people love. E-learning is one of the growth markets of the future - even more so during the current crisis.</p>\n<p>We are looking for a developer to help us improve our current e-learning solution, build new features, increase the user experience and maintain high standards in terms of our technical setup. We are looking to improve our CI/CD pipeline, improve observability and monitoring and continuously strive to automate what is reasonable to be automated. We work and make decisions together and address mistakes as a chance to learn and improve.</p>\n<p><strong>Your mission</strong></p>\n<ul>\n<li>Help maintain and extend our current learning platform</li>\n<li>Participate in the design, development and maintenance of new systems and components</li>\n<li>Automate our internal and public-facing infrastructure</li>\n<li>Document our system landscape, including decision documents and overview diagrams</li>\n<li>Implement reliable logging and monitoring solutions</li>\n<li>Ensure security and data compliance throughout our services</li>\n<li>Help customers, both prospective and current, to make the best use of our platform by contributing to the user experience</li>\n<li>Work with our customer success and sales teams to help them onboard and support  customers</li>\n</ul>\n<p><strong>Your profile</strong></p>\n<ul>\n<li>Bachelor’s Degree in Computer Science, Software Engineering, Computer Engineering or demonstrable similar experience</li>\n<li>Strong English language skills, written as well as oral</li>\n<li>2+ years of working experience as a service reliability engineer, platform engineer, backend engineer, or similar</li>\n<li>Very good understanding of Linux server administration, networking, distributed systems, security best practices</li>\n<li>Experience with log and metric collection</li>\n<li>Experience with automation (Infrastructure as Code, Configuration Management)</li>\n<li>Experience with networking, distributed systems and cloud technology</li>\n<li>Experience or willingness to learn how to design, develop, test and maintain web applications and associated services (for instance with Python, Go or Ruby)</li>\n<li>Ability to work independently, as well as an effective part of the team</li>\n<li>Any lack of experience in the above can be compensated by a great attitude towards continuous learning and self-improvement</li>\n</ul>\n<p><strong>Why us?</strong></p>\n<p>Why us?\nWe take care of our employees and provide you with:</p>\n<ul>\n<li>Flexible working hours with the option to work partially remote (fully remote during the pandemic)</li>\n<li>Modern computer and huge 4k screens</li>\n<li>A diverse and international environment</li>\n<li>A modern workplace close to the Berlin central station</li>\n<li>Special employee offers for sports clubs, gadgets, fashion, ....</li>\n<li>And a lot of fun :)</li>\n</ul>\n<p><strong>Our interview process</strong></p>\n<ul>\n<li>First video call: 1 hour with our IT Team Lead and one backend developer</li>\n<li>A home assignment which can be done within 1 hour</li>\n<li>A follow-up video call with a chance to discuss your approach and to meet more of the team</li>\n<li>A video call with our COO</li>\n</ul>\n<p>We are looking forward to seeing you!</p>\n<p><img src="https://camo.githubusercontent.com/8a7877a43fa91801f1ccdcd63e790769117b8afd/68747470733a2f2f742e676f686972696e672e636f6d2f682f31666161363462633661326430373462313733633630306430313731643762313435343832363632363963663537616537346131376463646130306536323761"></p>\n',
#   'how_to_apply': '<p><a href="https://t.gohiring.com/h/7f427001480f1cae28d00b35f2e9bd0924e559b9879c933610c9a4cd3ebdb650">application form</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBaEdpIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--7c379bf64f1fce3dcdbe3bfc67c21a521ab048b7/lawpilots%20GmbH.png'},
#  {'id': 'd0afa0c1-2ff5-4bb4-acc6-911eb06a2013',
#   'type': 'Contract',
#   'url': 'https://jobs.github.com/positions/d0afa0c1-2ff5-4bb4-acc6-911eb06a2013',
#   'created_at': 'Mon Apr 26 15:33:08 UTC 2021',
#   'company': 'Fullstack',
#   'company_url': 'http:',
#   'location': 'Anywhere',
#   'title': 'React Native Engineer',
#   'description': '<p><strong>React Native Mobile Engineer</strong></p>\n<p>Fullstack is looking for a motivated full-stack mobile engineer who will help develop and contribute to world class applications and products. You will have the opportunity to work on all aspects of our mobile application stack, from mobile app development in react native to backend api development in Ruby on Rails.  You will be joining a close knit group of very talented designers, engineers, and product managers that have a great time building software that makes a difference.</p>\n<p><strong>Primary Responsibilities</strong></p>\n<ul>\n<li>Drive development of our mobile applications, from architecture, to coding, to release.</li>\n<li>Take ownership in developing and improving all aspects of our stack (development, testing, CI, automation, and architecture)</li>\n<li>Release to both iOS and Android (Apple App Store, Google Play Store)</li>\n<li>Assist in development and maintenance of web-based backend API services</li>\n<li>Designing and engineering features that deliver value to the people who use them.</li>\n<li>Collaborating closely with the entire team (designers, product managers, etc.)</li>\n</ul>\n<p><strong>About FullStack</strong></p>\n<p>Our mission is to make our clients incredibly successful by developing and improving ideas into highly functional and usable web applications. Our team has become renowned in our ability to bring creativity, expertise, and sound development practices to notable and ambitious startups. Our development work focuses on architecting and building new applications as well as scaling existing apps for our clients as they grow.</p>\n<p><strong>Let’s Have A Chat If You…</strong></p>\n<ul>\n<li>Have developed React Native apps that communicate with Restful APIs, network data synchronization, and user authentication.</li>\n<li>Have a working knowledge of the Expo platform for React Native.</li>\n<li>Understand and have experience making decisions about mobile application architecture, including data modeling, networking and data synchronization, and concurrency.</li>\n<li>Are self-directed and able to manage your time effectively</li>\n</ul>\n<p><strong>Bonus points for…</strong></p>\n<ul>\n<li>Being experienced working in Ruby, and knowing your way around the Rails framework.</li>\n<li>iOS or Android development experience using Objective-C, Swift, or Android</li>\n<li>Experience working with high availability server architectures in AWS.</li>\n<li>Knowing your way around XCode or Android Studio</li>\n<li>Previous history of working with a remote, distributed team</li>\n</ul>\n<p><strong>Other information about this position</strong></p>\n<ul>\n<li>Working remotely is how we operate</li>\n<li>This is a per-project, contract position, with up to 40 hours per week</li>\n<li>We are looking for people located within the 4 US time zones.</li>\n</ul>\n',
#   'how_to_apply': '<p>Complete the online application at <a href="https://gofullstack.com/job-application/">https://gofullstack.com/job-application/</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBZytpIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--b2e8d8a94d87e84139c2b8ba7cbc54469019ee29/fullstack-logo-mark.png'},
#  {'id': '19917880-abc4-4f57-a9e3-27280d430fcc',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/19917880-abc4-4f57-a9e3-27280d430fcc',
#   'created_at': 'Mon Apr 26 14:06:23 UTC 2021',
#   'company': 'smartmicro',
#   'company_url': 'https://www.smartmicro.com',
#   'location': 'Brunswick, Braunschweig, Germany',
#   'title': 'C++ Developer (m/w/d)',
#   'description': '<p>smartmicro entwickelt Radarsensoren für automobile Fahrerassistenzsysteme, die das Autofahren sicherer und bequemer machen, vor allem für das automatische Fahren. smartmicro produziert außerdem Radarsysteme für die Infrastruktur von Smart Cities: zur Verkehrserfassung und -steuerung; für intelligente Kreuzungen und Straßen: Radarsensoren, die jeden Verkehrsteilnehmer, vom Fußgänger bis zum LKW, erfassen und den Verkehr optimal steuern können. In den Connected Vehicles der Zukunft treffen beide smartmicro Technologien zusammen: smarte Infrastruktur sendet per Car-2-X Kommunikation Informationen oder Warnungen an die Fahrzeuge. Autos mit smartmicro Sensorik können die Umgebung 360 Grad rings um ein Fahrzeug erkennen, mit Car-2-X Daten kombinieren und in Gefahrsituationen Unfälle vermeiden. smartmicro ist Innovation. Wir sind mit den modernsten Messverfahren, mit intelligenter Embedded Signalverarbeitungssoftware, führender Antennen- und Hochfrequenztechnologie stark aufgestellt. Wir bieten Produkte mit international führender, patentierter Technologie an.</p>\n<p><strong>Aufgaben</strong></p>\n<ul>\n<li>Plattformentwicklung für die nächste Generation Radar Sensoren</li>\n<li>Entwicklung und Integration von Middlewarekomponenten und Kommunikationsstacks</li>\n<li>Verifikation im Rahmen von Reviews und Anwenden von</li>\n<li>Testverfahren (Modultests, HIL/SIL-Tests)</li>\n<li>Erstellung von technischen Konzepten und Spezifikationen für die</li>\n<li>Software und Implementierung dieser auf Linux Systemen mittels C++</li>\n</ul>\n<p><strong>Qualifikation</strong></p>\n<ul>\n<li>mehrjährige Erfahrung in C++</li>\n<li>gute Kenntnisse im Bereich Software Design/Architektur</li>\n<li>Linux Entwicklung für Embedded Systeme</li>\n<li>Kenntisse unterschiedlicher Prozessor Architekturen</li>\n<li>Fehlersuche auf Embedded Linux Devices (JTAG-Debugging, KDB, GDB, etc..)</li>\n<li>von Vorteil: Erfahrung in C++11,C++17, Python Erfahrung mit Netzwerkprotokollen Inter Process Communcation(IPC) Protokolle z.B. DBUS,SOME/IP,RPC</li>\n</ul>\n<p><strong>Benefits</strong></p>\n<ul>\n<li>Neueste Technologie</li>\n<li>Ein angenehmes Arbeitsumfeld in einem motivierten Team</li>\n<li>Geräumige Büros und Labore in hochmodernen Gebäuden</li>\n<li>Weiterbildungsmöglichkeiten, Offenheit für Innovation und keinerlei Bürokratie</li>\n<li>Flexible Arbeitszeiten und Möglichkeiten für mobiles Arbeiten</li>\n<li>Unbefristeter Arbeitsplatz</li>\n<li>Fitnesstraining, Firmenevents und noch mehr auf Firmenkosten</li>\n<li>Kostenfreies Laden von Elektro- und Hybridelektrofahrzeugen</li>\n</ul>\n<p><strong>Lassen Sie sich von unserem Erfinder- und Pioniergeist anstecken und arbeiten Sie mit am Ausbau unserer Spitzentechnologie.</strong></p>\n',
#   'how_to_apply': '<p><a href="https://smartmicro.join.com/jobs/2179555-c-developer-m-w-d?pid=357a3b4531918760973f&amp;oid=38a90743-0554-46ed-9178-9c5b194ae017&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=c%2Bdeveloper%2Bm%2Bw%2Bd">https://smartmicro.join.com/jobs/2179555-c-developer-m-w-d?pid=357a3b4531918760973f&amp;oid=38a90743-0554-46ed-9178-9c5b194ae017&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=c%2Bdeveloper%2Bm%2Bw%2Bd</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBZ21pIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--b3bc1ab6129e72dc53b3d1beed2400032bec650b/smartmicro-logo-l.jpg'},
#  {'id': '01e82177-cb13-4026-bbc3-c309765347e2',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/01e82177-cb13-4026-bbc3-c309765347e2',
#   'created_at': 'Mon Apr 26 12:50:24 UTC 2021',
#   'company': 'Kontist GmbH',
#   'company_url': 'https://kontist.com/home/?mrasn=702727.872066.68AozIm3',
#   'location': 'Berlin',
#   'title': 'Senior JavaScript Developer (f/m/x)',
#   'description': "<p>Do you know how many obstacles freelancers face when it comes to their finances?</p>\n<p>It starts with opening a business account and leads to taking care of all the tax issues. We want to make it easy to run your own business when being self-employed and offer tailored services that address the pressing, and unique needs freelancers face.</p>\n<p>First we created a smart mobile bank account with superpowers that helps with finances, taxes and savings. Now we also offer a tax service for the self-employed to really take care of all of their needs. After a Series B funding we’re expanding our engineering team and looking for engineers who want to be part of taxes automation in Germany.</p>\n<p>You’ll work as a member in our cross-functional teams and ensure that we create a system and architecture that helps the company and our customers.</p>\n<p><strong>Your tasks:</strong></p>\n<ul>\n<li>Work on frontend (mobile and web apps) as well as backend tasks</li>\n<li>Help us within the conception, development and optimization of algorithms and applications with a focus on machine learning</li>\n<li>Implement new features and fix bugs</li>\n<li>Come up with ideas and suggestions to improve our processes and standards</li>\n<li>Spread your knowledge in the team and mentor junior developers to fulfill their potential</li>\n</ul>\n<p><strong>Your profile:</strong></p>\n<ul>\n<li>5+ years of experience in backend/API technologies - we use NodeJS, PostgreSQL and write things in TypeScript</li>\n<li>Strong frontend skills - we build our web apps with React and our mobile apps with React Native and mainly use Redux and React Hooks.</li>\n<li>An eye for quality (automated tests, clean code, striving for improvements)</li>\n<li>Experience with implementing REST APIs / GraphQL and CI/CD process</li>\n</ul>\n<p><strong>Your future team:</strong></p>\n<p>We are a team of engineers who are from 10+ countries and enjoy working with each other day by day. Below you can find our beliefs which unite us:</p>\n<ul>\n<li>Knowledge is like good news, it is best if you share it</li>\n<li>Responsibility is like bad news, it’s best not to be alone</li>\n<li>We embrace iteration</li>\n<li>Multitasking kills efficiency</li>\n<li>Software is not an island</li>\n<li>All for one, one for all</li>\n<li>Let's have fun</li>\n</ul>\n<p><em>We expect that everyone in our team:</em></p>\n<ul>\n<li>Takes ownership</li>\n<li>Gives constructive feedback</li>\n<li>Embraces change</li>\n<li>Communicates proactively</li>\n<li>Understands and questions specifications</li>\n</ul>\n<p><strong>How we show our love:</strong></p>\n<ul>\n<li>Decide if you want to work on-site or 100% remote.</li>\n<li>Flexible, trust-based working hours</li>\n<li>Great team that loves to grow</li>\n<li>Bring in your ideas (from machine learning to deployment)</li>\n<li>Personal coaching</li>\n<li>A multicultural, diverse, and inclusive community where you can grow personally and professionally, including possibilities to move internally within the company</li>\n<li>Lovely, sunny and green office in central Berlin with office dogs</li>\n<li>Regular team events and company off-sites</li>\n<li>Weekly German and English classes</li>\n<li>Sponsored daily on-site lunches</li>\n<li>Urban Sports Club membership</li>\n</ul>\n<p>We know that time is precious and this is why we try to keep our recruiting process short. You’ll meet directly in the first interview min. 2 of our team leads to get directly an idea about our culture and the people behind. We are looking forward to getting to know you!</p>\n",
#   'how_to_apply': '<p><a href="https://kontist.join.com/jobs/2133729-senior-javascript-developer-f-m-x?pid=357a3b4531918760973f&amp;oid=fec1ffbb-3fa7-4f27-8698-f629520d92bf&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=senior%2Bjavascript%2Bdeveloper%2Bf%2Bm%2Bx">https://kontist.join.com/jobs/2133729-senior-javascript-developer-f-m-x?pid=357a3b4531918760973f&amp;oid=fec1ffbb-3fa7-4f27-8698-f629520d92bf&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=senior%2Bjavascript%2Bdeveloper%2Bf%2Bm%2Bx</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBZ1NpIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--74f1f1c648204196ac8d07f8681945813a04b9a3/kontist-squarelogo-1533721173355.png'},
#  {'id': '33fa9582-fbd3-4735-b1f2-dd9d978e2549',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/33fa9582-fbd3-4735-b1f2-dd9d978e2549',
#   'created_at': 'Sun Apr 25 04:44:57 UTC 2021',
#   'company': 'DevStar Jobs',
#   'company_url': 'https://devstarjobs.com',
#   'location': 'Nashville, TN',
#   'title': 'Senior Engineer Ruby on Rails',
#   'description': '<p>Be part of a great team building the next generation hiring platform for software development jobs.</p>\n<p><strong>Your role?</strong></p>\n<ul>\n<li>Collaborate with team members to solve challenging engineering problems</li>\n<li>Build customer-first solutions</li>\n</ul>\n<p><strong>Your contributions?</strong></p>\n<ul>\n<li>Broad web development experience with Ruby and Rails</li>\n<li>Crisp communication</li>\n<li>Focus on project adaptability and manageability at the architecture level</li>\n</ul>\n<p><strong>Why apply?</strong></p>\n<ul>\n<li>Work on a small, agile (lowercase agile!) team without administrative overhead</li>\n<li>Remote first, flexibility for Life – because it happens</li>\n<li>Help fellow software developers by connecting them with hiring companies with a simple, straightforward process, without all the hassle of spammy notifications</li>\n</ul>\n<p><em>Diversity and equal opportunity are important to us. We are happy about the interest of all candidates and strive to provide feedback as quickly as possible.</em></p>\n',
#   'how_to_apply': '<p>Email CV and GitHub username to <a href="mailto:devstarjobs@protonmail.com">devstarjobs@protonmail.com</a></p>\n',
#   'company_logo': None},
#  {'id': '21a5ad81-2237-4544-b5d7-258b59d84cd5',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/21a5ad81-2237-4544-b5d7-258b59d84cd5',
#   'created_at': 'Fri Apr 23 09:02:57 UTC 2021',
#   'company': 'Randstad Groep Nederland B.V.',
#   'company_url': 'https://www.werkenbijrandstad.nl/',
#   'location': 'Diemen/Amsterdam',
#   'title': 'DevOps Engineer',
#   'description': "<p>Wil jij samen met onze ontwikkelaars kwalitatieve oplossingen realiseren door jouw ervaring als DevOps engineer in te zetten voor de platform services voor onze business applicaties? In een omgeving waarin experimenteren, vrijheid en jouw ontwikkeling centraal staat? Dan is het zeker de moeite waard om verder te lezen!</p>\n<p><strong>OVER RANDSTAD GROEP NEDERLAND IT</strong></p>\n<p>De IT-afdeling van Randstad Groep Nederland is verantwoordelijk voor de volledige ICT-dienstverlening, waaronder het ontwikkelen van applicaties. De developers van RGN IT ontwikkelen IT-oplossingen die mens en werk dichter bij elkaar brengen. Als DevOps engineer ondersteun je hen bij de ontwikkeling van deze applicaties.</p>\n<p><strong>WAT GA JE DOEN?</strong></p>\n<p>Als DevOps Engineer bij Randstad Groep IT zul je verantwoordelijk zijn voor het optimaal inrichten en opzetten van de platform services binnen RGN-IT. Deze platform services bieden ondersteuning aan de ontwikkelteams op het gebied van:</p>\n<ul>\n<li>Monitoring</li>\n<li>CI/CD</li>\n<li>Event bus</li>\n<li>Integratie</li>\n</ul>\n<p>In een gemiddelde werkweek hou jij je bezig met het onderhouden van de verschillende platform services, het ondersteunen van de ontwikkelteams, het verbeteren van de platform services, en het implementeren van de platform services binnen RGN-IT. Als je energie krijgt van een cloud omgeving, innovatie en uitdaging, dan zit je goed!</p>\n<p><strong>MET WIE WERK JE SAMEN?</strong></p>\n<p>Binnen RGN IT zal je werken binnen het Cloud Infra Solutions domein, waar binnen teams met verschillende expertisegebieden werken aan een beter en veiliger Randstad. Zo zijn naast het Cloud Infrastructure Services (CIS)  ook het Security Operations Center (SOC) &amp; Security Test Team (STT) onderdeel van dit domein. Het doel van het domein is om zowel qua infrastructuur als security Randstad Groep Nederland verder te brengen.</p>\n<p>Daarnaast werk je heel veel samen met meerdere ontwikkel/DevOps teams.In totaal hebben wij zo’n 26 DevOps teams in onze IT organisatie, met in totaal meer dan 250 collega’s. We werken veel samen in cross-functional product teams volgens een agile werkwijze, maar blijven ook graag bij elkaar aangesloten, door bijvoorbeeld onze chapters.</p>\n<p>Wist je trouwens dat ruim 30% van onze IT-professionals vrouw is? Best uitzonderlijk voor een IT-organisatie. En hartstikke mooi. Want we weten: hoe diverser de teams, hoe beter de resultaten.</p>\n<p><strong>WIE BEN JE?</strong></p>\n<p>Jij zou goed binnen Randstad Groep IT passen wanneer je de interesse hebt om veel te leren en uitdaging ziet in snelle ontwikkelingen. Jij vindt het leuk om verder te kijken dan jouw eigen werkveld en helpt jouw collega’s ook graag verder waar je dat kan. Verder vinden we het belangrijk dat jij:</p>\n<ul>\n<li>Werkervaring hebt als developer</li>\n<li>Ervaring hebt met scripting-talen, provisioning tool (zoals puppet, jenkins), test tools (zoals SonarQube)</li>\n<li>Kennis hebt van ELK, Enterprise Bus technologie, source control tools, CI/CD tools</li>\n<li>En brede interesse (of nog beter ervaring) hebt in Amazon Web Services, zodat je in meerdere disciplines aan de slag kunt</li>\n</ul>\n<p>We zoeken iemand met de volgende eigenschappen:</p>\n<ul>\n<li>HBO/WO werk- en denkniveau</li>\n<li>ca. 3 jaar ervaring in het werkgebied</li>\n<li>Ambitie om je verder te ontwikkelen</li>\n<li>Goede kennis van de Engelse taal, en bij voorkeur de Nederlandse taal</li>\n<li>Een analytisch en pragmatisch houding</li>\n<li>Klant- en oplossingsgericht</li>\n<li>In staat om risico's en passende niveaus van urgentie effectief te beoordelen en te communiceren aan zowel management als technisch personeel.</li>\n<li>Je bent een teamplayer</li>\n</ul>\n<p><strong>WAT BIEDEN WIJ?</strong></p>\n<ul>\n<li>Een divers applicatielandschap waar alle aspecten van het vakgebied aan bod komen, zodat je je volledig kan ontplooien als encryptie specialist.</li>\n<li>Een bruto maands ...
#   'how_to_apply': '<p>Ga direct naar <a href="https://www.werkenbijrandstad.nl/nl/nl/apply?jobSeqNo=RANEUKR18496EXTERNALNLNL&amp;utm_source=github&amp;utm_medium=paid&amp;utm_campaign=cr-it"><strong>het sollicitatieformulier</strong></a>!</p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdm1oIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--1c244327c16376573a204c24dc4da4a99875f384/randstad-logo-share-blue.png'},
#  {'id': 'a19f3597-9ebc-4e05-bc33-1d8c9e5d86bc',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/a19f3597-9ebc-4e05-bc33-1d8c9e5d86bc',
#   'created_at': 'Fri Apr 23 08:48:46 UTC 2021',
#   'company': 'Randstad Groep Nederland B.V.',
#   'company_url': 'https://www.werkenbijrandstad.nl/',
#   'location': 'Diemen/Amsterdam',
#   'title': 'Java/Hippo Developer',
#   'description': '<p>Randstad is een pionier in de hr-dienstverlening. Sinds de oprichting in 1960 zijn wij uitgegroeid tot dé grootste hr-dienstverlener in de wereld. Onze missie is om de wereld van werk te ontwikkelen. Dit doen wij voor iedereen die met werk te maken heeft: onze klanten, kandidaten, medewerkers en de maatschappij als geheel. In de hele wereld, en zeker ook in onze thuismarkt Nederland.</p>\n<p>Door onze passie voor mensen te combineren met de kracht van de hedendaagse technologie en innovatie, ondersteunen we mensen en organisaties bij het realiseren van hun ware potentie. Dit noemen we human forward.</p>\n<p><strong>RANDSTAD GROEP NEDERLAND IT</strong></p>\n<p>We werken normaal gesproken vanuit ons hoofdkantoor in Amsterdam (Diemen), op dit moment vanuit ons thuiskantoor. Een ondernemende agile omgeving waar we in meer dan 24 DevOps-teams continu experimenteren met nieuwe technologieën. Hoe wij zorgen dat Randstad Groep Nederland IT wereldwijd voorop blijft lopen als het gaat om IT-innovatie? Door elkaar scherp te houden en te inspireren in onze zogenoemde tribes. Doordat wij met meerdere tribes aan eenzelfde product of dienst werken, ontstaat een interessante kruisbestuiving tussen collega’s van allerlei teams en disciplines binnen én buiten de IT-afdeling. Wat ongetwijfeld ook bijdraagt aan ons succes, is de diversiteit binnen onze teams. Wist je bijvoorbeeld dat ruim 30% van onze IT-professionals vrouw is? Dat kunnen maar weinig IT-organisaties zeggen. Wij zijn er trots op, want we weten: gemengde teams – in de meest brede zin van het woord – presteren beter.</p>\n<p><strong>HET TEAM WAAR JE KOMT TE WERKEN</strong></p>\n<p>Je komt te werken in het Online Search Experience team. Dit team werkt samen met de product owner aan onze web omgevingen van Randstad Groep Nederland. Het team bestaat uit 4 full stack developers, 1 frontend developer, 1 analist en 1 UX-designer. Naast het team zijn we binnen de IT organisatie bezig met het opzetten van chapters. In het chapter komen medewerkers met dezelfde expertise samen om het vakmanschap binnen onze organisatie te vergroten en om standaarden op gebied van documentatie, werkwijze en coding op elkaar af te stemmen. We gebruiken Hippo als ons CMS, daardoor is het van belang dat je hier al de nodige kennis van hebt.</p>\n<p><strong>WAT GA JE DOEN?</strong></p>\n<p>Als Developer werk je met het volgende takenpakket:</p>\n<ul>\n<li>Samen met het team ontwikkelen van user stories op de backlog;</li>\n<li>Samenwerken met andere online teams;</li>\n<li>Testen schrijven voor de code die je oplevert.</li>\n</ul>\n<p><strong>WIE BEN JE?</strong></p>\n<p>We werken met onderstaande technieken, we verwachten dat je de meeste al onder knie hebt:</p>\n<ul>\n<li>Bloomreach / Hippo CMS (must have)</li>\n<li>Spring, springboot</li>\n<li>Swagger</li>\n<li>Java &amp; object oriented</li>\n<li>Json &amp; rest services</li>\n<li>Soap-services &amp; wsdl</li>\n<li>XML, xsd, yaml</li>\n<li>Jenkins</li>\n<li>Git &amp; gitlab</li>\n<li>Kibana</li>\n<li>Maven &amp; Gradle</li>\n</ul>\n<p><strong>SKILLS &amp; COMPETENTIES DIE VOOR DEZE ROL VAN BELANG ZIJN:</strong></p>\n<ul>\n<li>Nederlands en Engels in woord en geschrift;</li>\n<li>Je hebt een allround mentaliteit / hands-on mentaliteit / self-starting;</li>\n<li>Je hebt sterke affiniteit met het werken in een dynamische omgeving waarin de gestelde eisen aan kwaliteit hoog zijn en je hebt een Agile mindset;</li>\n<li>Je werkt gestructureerd, je bent analytisch en je kan outside-the-box zaken benaderen;</li>\n<li>Je hebt een klant- en oplossingsgerichte instelling en gaat geen uitdaging uit de weg;</li>\n<li>Beschikt over ambitie en lef; je wilt jezelf continu kunnen (blijven) uitdagen en verbeteren;</li>\n<li>Je voelt je thuis in een technisch complexe omgeving en je deinst niet terug van het vinden van oplossingen die op dat moment buiten jouw ervaringsgebied liggen.</li>\n</ul>\n<p><strong>WAT BIEDEN WIJ?</strong></p>\n<ul>\n<li>Een divers ...
#   'how_to_apply': '<p>Ga direct naar <a href="https://www.werkenbijrandstad.nl/nl/nl/apply?jobSeqNo=RANEUKR17917EXTERNALNLNL&amp;utm_source=github&amp;utm_medium=paid&amp;utm_campaign=cr-it"><strong>het sollicitatieformulier</strong></a>!</p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdXVoIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--a5004f57dc432a95ce112bc6c5b177e770c9ec0e/randstad-logo-share-blue.png'},
#  {'id': '4502c26a-af2f-4cd1-a3e4-a25cf813bfbf',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/4502c26a-af2f-4cd1-a3e4-a25cf813bfbf',
#   'created_at': 'Fri Apr 23 08:23:08 UTC 2021',
#   'company': 'Randstad Groep Nederland B.V.',
#   'company_url': 'https://www.werkenbijrandstad.nl/',
#   'location': 'Diemen/Amsterdam',
#   'title': 'Data Engineer',
#   'description': '<p>Data Engineer, Everyday people employed through Randstad make sure your luggage gets onto the plane, your takeaway into your kitchen and that our most vulnerable are cared for. Everytime we place someone into a new role, they make an impact on our society, and we make an impact on their and their employer’s future. As a more and more data-driven organisation, data is a vital part of delivering on the promises we make to our candidates and customers.</p>\n<p>Randstad, Yacht and Tempo-Team possess an enormous quantity of data: the characteristics of millions of candidates and business data on clients, potentials and our own organisation. Your team, DataHub, is responsible for providing the basis for our data infrastructure. Our data engineers work on a self-service data platform, making sure our data makes its way from a vast array of sources to the right place, enabling our Data Scientists and Operational Insights teams to for example build AI solutions.</p>\n<p><strong>DATA ENGINEER TEAM</strong></p>\n<p>The DataHub team is an agile team of 8 data engineers. The datalake we maintain is partly in Redshift, partly in S3. We created a Django based metadata catalog, that functions in the same time as a portal to monitor the data and to provide services for our consumers.</p>\n<p>For general usage we offer the functionality of data subscriptions through scheduled unloads to a project space on S3. Furthermore we offer tools to work with machine learning models using Sagemaker.</p>\n<p>The Data Engineer will be designing and setting up infrastructure on AWS for the expanding services of our platform and develop airflow dags that represent our data pipelines. Most of our coding is done in python.</p>\n<p><strong>WHAT WILL YOU BE DOING AS A DATA ENGINEER?</strong></p>\n<p>You will be part of an agile Data Engineer team and play a vital role in the design and development of a cloud-based data platform.</p>\n<p>You will build and manage the DataHub frontend, which includes;</p>\n<ul>\n<li>A data catalog;</li>\n<li>DataHub users and projects management;</li>\n<li>Data subscriptions;</li>\n<li>etc.</li>\n</ul>\n<p>Develop ways to improve self-service data consumption and data publishing:</p>\n<ul>\n<li>Build and manage ETL pipelines in Airflow, which are responsible of ingesting the data and making the data available to users;</li>\n<li>Develop standard ways to deliver data in the DataHub;</li>\n<li>Develop CI/CD pipelines for data consuming teams to let them develop their products;</li>\n<li>etc.</li>\n</ul>\n<p>The Data Engineer will be responsible of producing high quality code and reusable components. Using containerization, CI/CD and other automation technologies, you will be responsible for creating a backend for high availability and scalability, while at the same time being easily deployable, manageable and secure.</p>\n<p>Together with the rest of the team you will be involved in the full product development process, from design, implementation, to testing, documentation and automated deployment.</p>\n<p>Respond to and resolve operational incidents, performing root cause analysis and managing changes required to prevent future occurrences.</p>\n<p>In this team you will have a wide range of responsibilities and should be willing to adapt to many different challenges.</p>\n<p>Discuss with the users of the platform requirements and future improvements, but also come with proposals for our user on how to use the platform.</p>\n<p>Manage and develop our data persistence environments (data lake, storage, etc) to ensure that data is properly available to users and secured</p>\n<p>Monitor systems for uptime and performance.</p>\n<p><strong>WHAT IS OUR STACK?</strong></p>\n<ul>\n<li>Python;</li>\n<li>ECS, Docker;</li>\n<li>CloudFormation, Jenkins;</li>\n<li>Airflow;</li>\n<li>AWS (S3, EC2, ECS, lambda, RDS, Redshift, EMR Spark, Athena, Glue).</li>\n</ul>\n<p><strong>WHAT WE WOULD LIKE YOU TO KNOW AND BRING TO THE TABLE ...
#   'how_to_apply': '<p>Apply directly through <a href="https://www.werkenbijrandstad.nl/nl/nl/apply?jobSeqNo=RANEUKR18598EXTERNALNLNL&amp;utm_source=github&amp;utm_medium=paid&amp;utm_campaign=cr-it"><strong>the application form</strong></a>!</p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdWloIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--9cc2304d0d0f55e04318a962f1ae39008fb08adf/randstad-logo-share-blue.png'},
#  {'id': '8a3f8470-78be-41c9-acf6-dff2967ac96f',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/8a3f8470-78be-41c9-acf6-dff2967ac96f',
#   'created_at': 'Thu Apr 22 16:15:11 UTC 2021',
#   'company': 'Randstad Groep Nederland B.V.',
#   'company_url': 'https://www.werkenbijrandstad.nl/',
#   'location': 'Diemen/Amsterdam',
#   'title': 'Software Architect',
#   'description': '<p>Als je bij Randstad Groep Nederland IT werkt, houd je jezelf en Nederland in beweging. Stilstand is achteruitgang, daarom zijn we continu bezig onze business en processen te optimaliseren, zodat we onze klanten en kandidaten meer gemak, snelheid en transparantie kunnen bieden. Impactvolle tech, daar doen we het voor.</p>\n<p>Zo werken we in onze 24 devops teams aan onder andere customer experience initiatieven, state of the art tooling voor onze intercedenten, sales consultants en recruiters, en investeren we sterk in data, om data driven te werken binnen een menselijke wereld. Zo hebben we de talent recommender, een AI oplossing die binnen seconden passende kandidaten vindt; moderniseren wij onze kern door legacy systemen op te breken naar applicaties en verplaatsen we steeds meer naar de cloud.</p>\n<p><strong>WAT GA JE DOEN?</strong></p>\n<ul>\n<li>Je ondersteunt de lead enterprise archtiect met het geven van technische invulling aan de transformatie op business, technologie en persoonlijk vlak;</li>\n<li>Samen met de andere architecten werk je de roadmap van RGN IT uit;</li>\n<li>Nauw samenwerken met de product owners en tech leads, discussies begeleiden, sessies faciliteren om een op elkaar aansluitende, business ondersteunende visie en kwaliteitsstandaarden te creëren;</li>\n<li>Adviseren van productteams en developers op kwaliteitsnormen en verbeteringsmogelijkheden;</li>\n<li>Vertalen van strategie en functionele wensen naar verbeteringen in ons applicatielandschap;</li>\n<li>Samen met de andere architecten ben je het technisch geweten van RGN IT;</li>\n<li>Operationaliseren van architectuur, naast ‘as is’ en ‘to be’ ook de route hiernaartoe uitwerken.</li>\n</ul>\n<p><strong>MET WIE WERK JE SAMEN?</strong></p>\n<p>Als software architect werk je in ons architecture team, als onderdeel van onze foundation tribe, samen met 5 andere architecten onder leiding van de lead enterprise architect.Samen zijn jullie het technisch geweten van ons applicatielandschap en infrastructuur. Onze omgeving is hierbij voornamelijk gebaseerd op java en AWS, wij werken o.a. met Scala, Elasticsearch, Python, Docker en Airflow.</p>\n<p><strong>WIE BEN JE?</strong></p>\n<ul>\n<li>Je hebt zeer goede kennis van methodieken zoals SOA, TOGAF;</li>\n<li>Je hebt een technische achtergrond, als bijvoorbeeld developer, en bent in elk geval in staat om developers te adviseren en code te lezen;</li>\n<li>Je hebt kennis van API management, bouwen van software en integratie;</li>\n<li>Je hebt up to date kennis van security (SSO, openID connect);</li>\n<li>Je hebt kennis van data en informatie modellen;</li>\n<li>In een cloud omgeving voel je je thuis;</li>\n<li>Je bent communicatief sterk en in staat om met zowel developers als MT te schakelen op verschillende niveaus en doet dit comfortabel in zowel Nederlands als Engels;</li>\n<li>Ook al is programmeren geen dagelijkse taak meer, je vindt het leuk om zelf te puzzelen en hands-on dingen uit te proberen en mee te denken.</li>\n</ul>\n<p><strong>WAAROM RGN IT?</strong></p>\n<p>Tech en Touch. Wij geloven in de kracht van technologie, maar wél gecombineerd met persoonlijke aandacht. En dat geldt evengoed voor onze eigen medewerkers: wij zien jouw vooruitstrevende ideeën, maar vooral jou. Jouw werkplezier staat voorop. We zien jou als mens, en geven je de ruimte en ondersteuning om jouw beste zelf te zijn. Daarnaast bieden we:</p>\n<ul>\n<li>de kans om impact te maken op een groot transformatieproject;</li>\n<li>een interessant maandelijks salaris afhankelijk van je werkervaring;</li>\n<li>een benefit budget van 12,347% (incl. 8,5% vakantiegeld) dat je kan inzetten voor sport, extra opleidingsbudget, extra vrije tijd, of als leuke extra bonus;</li>\n<li>een lease auto of mobiliteitsbudget, laptop, telefoon en abonnement;</li>\n<li>25 vakantiedagen per jaar, met de optie er max. 26 bij te kopen;</li>\n<li>een interessante bonusregeling;</li>\n<li>de mogelijkheid om na 3 jaar een sabbatical  ...
#   'how_to_apply': '<p>Ga direct naar <a href="https://www.werkenbijrandstad.nl/nl/nl/apply?jobSeqNo=RANEUKR16983EXTERNALNLNL&amp;utm_source=github&amp;utm_medium=paid&amp;utm_campaign=cr-it"><strong>het sollicitatieformulier</strong></a>!</p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdGVoIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--38e47b1190f9c22b506812abe9a0fe4161cc4b85/randstad-logo-share-blue.png'},
#  {'id': '2db8422f-da05-4821-9c44-86f2c3448ea9',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/2db8422f-da05-4821-9c44-86f2c3448ea9',
#   'created_at': 'Thu Apr 22 17:52:33 UTC 2021',
#   'company': 'Randstad Groep Nederland B.V.',
#   'company_url': 'http://werkenbijrandstad.nl/',
#   'location': 'Diemen/Amsterdam',
#   'title': 'Fullstack Java Developer',
#   'description': "<p>Met jouw expertise zorg je als fullstack java developer voor de meest plezierige en efficiënte klantervaring. Met jouw state-of-the-art-systemen verbeter je onze business en maak je echt impact!\nWant als je in ons tech team werkt, houd je jezelf en Nederland in beweging. Wij zijn continu bezig onze business en processen te optimaliseren, zodat we onze klanten en kandidaten meer gemak, snelheid en transparantie kunnen bieden. Impactvolle tech, daar doen we het voor.</p>\n<p><strong>WAT GA JE DOEN?</strong></p>\n<ul>\n<li>Samen met het team ontwikkelen van user stories op de backlog;</li>\n<li>Begeleiden van (meer junior) collega’s;</li>\n<li>Samenwerken met andere online teams;</li>\n<li>Devops activiteiten ontplooien zoals productie incidenten oplossen en voorkomen</li>\n<li>Uitvoeren en automatiseren van (regressie) testen</li>\n<li>Technisch refinen van user stories</li>\n<li>Testwerk</li>\n</ul>\n<p><strong>WAAR WERK JE?</strong></p>\n<p>We werken vanuit ons hoofdkantoor in Amsterdam (Diemen). Een ondernemende agile omgeving waar we in meer dan 24 DevOps-teams continu experimenteren met nieuwe technologieën. Jouw team bestaat uit vier tot zes software ontwikkelaars, designers, analisten en testers.\nWe werken vanuit tribes. Door met meerdere tribes aan eenzelfde product of dienst te werken, ontstaat er een interessante kruisbestuiving tussen collega's van allerlei teams en disciplines binnen én buiten onze it afdeling. Zo houden we elkaar scherp en inspireren we elkaar. Maar natuurlijk blijf je binnen je eigen chapter ook brainstormen over ontwikkeling en technische problemen én schakel je met stakeholders in de organisatie, van product owners, security officers en directeuren; maar ook met eindgebruikers, recruiters, marketeers en kandidaten.</p>\n<p>Wat ongetwijfeld ook bijdraagt aan ons succes, is de diversiteit binnen onze teams. Zo zijn de vrouwen bij ons op de IT afdeling goed vertegenwoordigd met ruim 30%. Wij zijn er trots op, want we weten: gemengde teams – in de meest brede zin van het woord – presteren beter.</p>\n<p><strong>WIE BEN JE?</strong></p>\n<p>Jij hebt al wat jaren ervaring als software ontwikkelaar, uiteraard programmeer je voornamelijk in Java en ben je op zoek naar een plek waar je kan groeien. Daarnaast breng jij al wat ervaring met jou mee, namelijk:</p>\n<ul>\n<li>4 jaar aantoonbare ervaring in ontwikkelen van Java Webapplicaties, services (SOAP/REST) en business logica</li>\n<li>Java 8</li>\n<li>HTML / CSS / Javascript / Angular</li>\n<li>JSP</li>\n<li>JAVA Spring boot</li>\n<li>Docker Container</li>\n<li>Amazon AWS</li>\n<li>CI/CD</li>\n<li>ECS</li>\n</ul>\n<p>Jij hebt bij voorkeur ook ervaring met:</p>\n<ul>\n<li>Elasticsearch</li>\n<li>Gitlab / Jira / Jenkins / Kibana / Sonar</li>\n<li>Selenium / JUnit / Ready-API / SOAP-UI</li>\n<li>AWS</li>\n</ul>\n<p><strong>WAT BIEDEN WIJ?</strong></p>\n<ul>\n<li>Een warm bad, met fijne en inspirerende collega’s die voor je klaarstaan;</li>\n<li>Een leer/werktraject;</li>\n<li>Een marktconform salaris;</li>\n<li>25 vakantiedagen en 8,5% vakantietoeslag;</li>\n<li>Veel opleidingsmogelijkheden en ontwikkelkansen binnen Randstad Groep Nederland;</li>\n<li>Goede mobiliteitsregeling en laptop;</li>\n<li>Een ruim maandelijks benefit budget waarmee je zelf kunt kiezen tussen vrije tijd of geld of voor inzet van je budget voor oa een fiets, tablet, sportabonnement of opleiding;</li>\n<li>Een interessante bonusregeling met daarnaast mogelijkheid om 2x per jaar een outperformance bonus te behalen</li>\n</ul>\n<p><strong>WAAROM RGN IT?</strong></p>\n<p>Als je als fullstack java developer ergens impact hebt, dan is het hier wel. Wij ondersteunen onze HR-dienstverlening met hightech apps en software, die we continu verbeteren. Zodat onze mensen ervoor kunnen zorgen dat bijvoorbeeld jouw koffer op de band terecht komt op het vliegveld, jouw pakketjes netjes op tijd worden geleverd en goed verzorgt wordt in het ziekenhuis. Onze innovaties volgen elk ...
#   'how_to_apply': '<p>Ga direct naar <a href="https://www.werkenbijrandstad.nl/nl/nl/apply?jobSeqNo=RANEUKR18242EXTERNALNLNL&amp;utm_source=github&amp;utm_medium=paid&amp;utm_campaign=cr-it"><strong>het sollicitatieformulier</strong></a>!</p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdVNoIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--2eb5e267d5e57d8535d543fecb77c9fd029ad875/randstad-logo-share-blue.png'},
#  {'id': 'a9ec9eef-e7e5-4fe4-a44a-9bd1f0585628',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/a9ec9eef-e7e5-4fe4-a44a-9bd1f0585628',
#   'created_at': 'Fri Apr 23 13:28:48 UTC 2021',
#   'company': 'IT&I',
#   'company_url': 'https://iti-software.de',
#   'location': 'Berlin',
#   'title': 'Software Entwickler WPF / Angular (m/w/d)',
#   'description': '<p>Mit über 55 Mitarbeitern ist die IT&amp;I GmbH ein bundesweit agierendes in Berlin-Mitte ansässiges Unternehmen für Softwareentwicklung und -Beratung. Wir entwickeln und betreiben maßgeschneiderte Softwareanwendungen für die Energiewirtschaft. Dabei unterstützen wir unsere Kunden bei der Umsetzung der IT-Anforderungen in einem durch die Energiewende geprägten dynamischen Umfeld mit agilen Methoden.</p>\n<p><strong>Aufgaben</strong></p>\n<ul>\n<li>Du konzipierst und entwickelst innovative Software für Desktop-Anwendungen mit WPF</li>\n<li>Du migrierst gemeinsam mit deinem agilen Team eine umfangreiche WPF-Anwendung nach Angular</li>\n<li>Du verwendest C# .NET (Core) und Angular</li>\n<li>Durch vorgegebene Mock-ups setzt du die Designs um</li>\n<li>Du bindest Backend-Services an</li>\n<li>Du arbeitest eng mit dem Kunden zusammen</li>\n</ul>\n<p><strong>Qualifikation</strong></p>\n<ul>\n<li>Du hast mehrere Jahre Berufserfahrung als Software Entwickler und Erfahrung in der Umsetzung von Anwendungen mit WPF</li>\n<li>Du kennst dich in der Softwarearchitektur (MVVM) aus</li>\n<li>Ein Plus für dich wären Erfahrungen mit anderen Frameworks (Angular, React, EF), in der Backendentwicklung und mit Prozess- oder CI-Tools (Azure DevOps)</li>\n<li>Du bringst bereits Grundkenntnisse in relationalen Datenbanken mit</li>\n<li>Dependency Injection und Clean Code sind keine Fremdwörter für dich</li>\n<li>Du hast einen Fach- oder Hochschulabschluss der Informatik oder eine vergleichbare Qualifikation</li>\n<li>Du bist teamfähig, verfügst über Lernbereitschaft und Kommunikationsbereitschaft</li>\n<li>Du verstehst Zusammenhänge, schaust über den Tellerrand hinaus und hast die Bereitschaft dich mit neuen Technologien, Tools und Prozessen zu beschäftigen</li>\n<li>Du bringst gute Deutsch- und Englischkenntnisse mit</li>\n</ul>\n<p><strong>Benefits</strong></p>\n<ul>\n<li>Werde Teil eines kreativen Teams mit flachen Hierarchien und nutze die Chance gemeinsam mit uns zu wachsen</li>\n<li>Arbeite in unserem zentralen und modernen Büro in Berlin-Mitte</li>\n<li>Kostenfreie Getränke (Kaffee, Tee, Wasser, Mate), Obst und Süßigkeiten unterstützen deine Kreativität – mit unserer Siebträgermaschine kommen auch Kaffeeliebhaber auf ihre Kosten</li>\n<li>Wir haben flexible Arbeitszeiten und Homeoffice-Möglichkeiten</li>\n<li>Feier mit uns unsere Erfolge bei Teamevents oder Firmenfeiern (Beachvolleyball, Badminton, Firmenlauf, uvm.) und nutze zum Austausch unsere Gemeinschaftsküchen, Kicker, Nintendo Switch oder unser kleines Kino</li>\n<li>Du erhältst eine unbefristete Anstellung in einem sicheren und wachsenden Unternehmen</li>\n<li>Neben einem neuen Firmenhandy erwartet dich eine attraktive Vergütung</li>\n</ul>\n<p><strong>Wir haben dich neugierig gemacht?</strong></p>\n<p>Dann bewirb dich jetzt und sende uns deine aussagekräftige Bewerbung (deine Bewerbung sollte max. 10 Anhänge haben oder 10MB groß sein). Wir freuen uns auf dich!</p>\n',
# ...
#   'how_to_apply': '<p><a href="https://t.gohiring.com/h/ea1994f1cfb5c23d5af9328814caf32d855d6a0c097f67e40c7acb51d771d1f7">application form</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcE9lIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--6817c5a1d60a7857c0946eb8ece66b11bc967d57/Lampenwelt%20GmbH.jpg'},
#  {'id': 'fd66c52e-ea9f-4e73-a7a4-3a4a43c64fdb',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/fd66c52e-ea9f-4e73-a7a4-3a4a43c64fdb',
#   'created_at': 'Mon Mar 29 08:00:12 UTC 2021',
#   'company': 'DEVK Versicherungen',
#   'company_url': 'https://www.devk.de/',
#   'location': 'Germany (50735 Cologne)',
#   'title': 'Pega Entwickler (d/m/w)',
#   'description': '<p>Pega Entwickler (d/m/w)</p>\n<p>Seit mehr als 130 Jahren legen Versicherte in Deutschland ihre Risiken des Alltags vertrauensvoll in die Hände der DEVK Versicherungen. Heute ist die DEVK bundesweit präsent und betreut die persönlichen Anliegen von über vier Millionen Kunden in allen Versicherungssparten.</p>\n<p>In unserem Team "Akquiseanwendungen" entwickeln wir mit agilen Methoden auf der Plattform Pega eine neue CRM-Software, die von unseren Kunden und Mitarbeitenden bereits erfolgreich genutzt wird. Wenn Sie unser Team durch Ihr Wissen ergänzen und kontinuierlich weitere Skills in Coaching Sessions, Pair Programming, PEGA-Schulungen und einem intensiven Austausch im Team aufbauen wollen, sind Sie bei uns richtig!</p>\n<p>Ihre Aufgaben</p>\n<ul>\n<li>Entwicklung des DEVK-Vertriebssystems basierend auf aktueller Pega Version 8.4</li>\n<li>Umsetzung von Aufgaben in einem agilen Team</li>\n<li>Unterstützung bei der Analyse von fachlichen und technischen Anforderungen</li>\n<li>Stetige Weiterentwicklung Ihres technischen Know Hows in Pega</li>\n</ul>\n<p>Ihr Profil</p>\n<ul>\n<li>Erfolgreich abgeschlossenes (Wirtschafts-) Informatikstudium oder vergleichbare Ausbildung</li>\n<li>Erfahrungen im Bereich Softwareentwicklung</li>\n<li>Datenbankkenntnisse im Bereich PostgreSQL von Vorteil</li>\n<li>Spaß an eigenverantwortlichem Arbeiten in einem jungen und dynamischen Team</li>\n<li>Innovationsfähigkeit und Interesse an neuen technologischen Entwicklungen</li>\n<li>Offenheit das Angebot der DEVK zur permanenten Weiterentwicklung anzunehmen</li>\n</ul>\n<p>Unsere Benefits</p>\n<ul>\n<li>Sichere Arbeitsplätze in einem stetig wachsenden Unternehmen</li>\n<li>Eine hervorragende arbeitgeberfinanzierte betriebliche Altersversorgung</li>\n<li>Flexible Arbeitszeitmodelle</li>\n<li>Möglichkeit für Homeoffice / Mobiles Arbeiten</li>\n<li>Stark vergünstigtes Job-Ticket</li>\n</ul>\n<p>Informieren Sie sich über unsere weiteren Benefits. Wir freuen uns darauf, Sie persönlich kennenzulernen. Falls Sie noch Fragen haben, rufen Sie uns gerne an.</p>\n<p>Ihr Ansprechpartner\nTanja Willing\nTel.: +49 221 757-1154</p>\n',
#   'how_to_apply': '<p><a href="https://bewerbungsportal.devk.de/index">https://bewerbungsportal.devk.de/index</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcEdlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--af86e5d1b1c321d3a5b89fa9a217e17c8ee0b3ef/DEVK_logo_treffer.png'},
#  {'id': '7cab75c5-221f-4a1b-94b9-b02b86db00b9',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/7cab75c5-221f-4a1b-94b9-b02b86db00b9',
#   'created_at': 'Mon Mar 29 07:56:59 UTC 2021',
#   'company': 'DEVK Versicherungen',
#   'company_url': 'https://www.devk.de',
#   'location': 'Germany (50735 Cologne)',
#   'title': 'Spezialist (d/m/w) MSSQL & IIS',
#   'description': '<p>Spezialist (d/m/w) MSSQL &amp; IIS</p>\n<p>Seit mehr als 130 Jahren legen Versicherte in Deutschland ihre Risiken des Alltags vertrauensvoll in die Hände der DEVK Versicherungen. Heute ist die DEVK bundesweit präsent und betreut die persönlichen Anliegen von über vier Millionen Kunden in allen Versicherungssparten.</p>\n<p>Sie fühlen sich sind in der Welt von Windows Server Anwendungen und im Bereich IIS &amp; MS SQL zuhause? Als Spezialist MSSQL &amp; IIS kümmern Sie sich um die Bereitstellung von MS-SQL-Datenbanken und die MS-IIS Webserverdienste für unsere internen Kunden. Perspektivisch gestalten Sie zudem den Weg in die Cloud mit, damit unsere Anwendungen auch in einem Cloudkontext betrieben werden können.</p>\n<p>Ihre Aufgaben</p>\n<ul>\n<li>Bereitstellung, Optimierung und Wartung von Microsoft SQL-Datenbanken:</li>\n<li>Anpassung der Datenbanken</li>\n<li>Vergabe von Zugriffsrechten auf den SQL-Server</li>\n<li>Übertragung von Daten / Datenbanken zwischen Produktion und Testumgebungen</li>\n<li>Betrieb und Support der Schnittstellen der Anwendungen Richtung Datenbankserver (Microsoft SQL ODBC, OLEDB, Native Client)</li>\n<li>Konfiguration und Administration des Microsoft Webservers IIS (Einspielen von SSL Zertifikaten, Kerberos Authentifizierung, Pool Configuration…)</li>\n<li>Bereitstellung und Betreuung von IIS-Webservern zur Nutzung durch Fachanwendungen inklusive Sicherheitskonfiguration</li>\n<li>Enge Zusammenarbeit mit den Fachbereichen sowie Unterstützung und Beratung der anderen IT-Abteilungen</li>\n<li>Mitarbeit in Projekten</li>\n</ul>\n<p>Ihr Profil</p>\n<ul>\n<li>Erfolgreich abgeschlossenes IT-Studium oder entsprechende Ausbildung mit mehrjähriger Berufserfahrung</li>\n<li>Erfahrung in Entwicklung und Betrieb von Windows Server Umgebungen</li>\n<li>Sicherer Umgang mit Komponenten des Windows Server Betriebssystems und der relevanten Services</li>\n<li>Sehr gute Kenntnisse im Bereich Bereitstellung, Wartung und Optimierung von MS-SQL-Datenbanken</li>\n<li>Gute Kenntnisse des MS SQL-Server-Datenbanksystems auch im geclusterten Betrieb gepaart mit vertieften Kenntnissen in TSQL</li>\n<li>Einschlägige Erfahrungen mit den Microsoft IIS Webservices inklusive Verschlüsselungs- und Authentifizierungskonfiguration sowie Webtechnologien</li>\n<li>Ausbaufähige Grundkenntnisse der Scriptsprache Powershell</li>\n<li>Spaß an modernen Technologien und Freude daran neu Gelerntes weiterzugeben</li>\n</ul>\n<p>Unsere Benefits</p>\n<ul>\n<li>Sichere Arbeitsplätze in einem stetig wachsenden Unternehmen</li>\n<li>Eine hervorragende arbeitgeberfinanzierte betriebliche Altersversorgung</li>\n<li>Flexible Arbeitszeitmodelle</li>\n<li>Möglichkeit für Homeoffice / Mobiles Arbeiten</li>\n<li>Stark vergünstigtes Job-Ticket</li>\n</ul>\n<p>Informieren Sie sich über unsere weiteren Benefits. Wir freuen uns darauf, Sie persönlich kennenzulernen. Falls Sie noch Fragen haben, rufen Sie uns gerne an.</p>\n<p>Ihr Ansprechpartner\nTanja Willing\nTel.: +49 221 757-1154</p>\n',
#   'how_to_apply': '<p><a href="https://bewerbungsportal.devk.de/index">https://bewerbungsportal.devk.de/index</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBbytlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--9b79683449ca22f552b3ac6726bdd078dfbca867/DEVK_logo_treffer.png'},
#  {'id': '19a1259a-7802-41b3-96bb-88680b7cb9ad',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/19a1259a-7802-41b3-96bb-88680b7cb9ad',
#   'created_at': 'Mon Mar 29 07:50:17 UTC 2021',
#   'company': 'DEVK Versicherungen',
#   'company_url': 'https://www.devk.de',
#   'location': 'Germany (49324 Melle)',
#   'title': 'Kundenberater (m/w/d) in Melle',
#   'description': '<p>Kundenberater (m/w/d) in Melle</p>\n<p>Seit über 130 Jahren legen Versicherte in Deutschland ihre Risiken des Alltags vertrauensvoll in die Hände der DEVK. Um die Anliegen unserer Kunden kümmern sich tagtäglich rund 6.000 Mitarbeiter in 1.250 Geschäftsstellen, 19 Regionaldirektionen und der Unternehmenszentrale in Köln.</p>\n<p>Für die Betreuung unserer Kunden suchen wir engagierte Außendienstmitarbeiter. Sie werden in einer DEVK-Geschäftsstelle eingesetzt, arbeiten dort eng mit dem Agenturteam zusammen und sind beim Agenturleiter angestellt.</p>\n<p>Ihre Aufgaben</p>\n<ul>\n<li>Individuelle Betreuung unserer langjährigen Privat- und Geschäftskunden in allen Versicherungsfragen</li>\n<li>Ausbau des Agenturbestandes durch die Gewinnung neuer Kunden</li>\n<li>Aktive regelmäßige Ansprache Ihrer Bestandskunden zum Aufbau dauerhafter Geschäftsbeziehungen</li>\n<li>Schadenmanagement und Regulierung von Kleinschäden</li>\n<li>Konsequentes Cross-Selling</li>\n<li>Eigenverantwortliches Arbeiten ‒ bei Bedarf mit Unterstützung durch unsere Vertriebsprofis</li>\n<li>Kontinuierliche Weiterbildung und Nutzung unserer Angebote des DEVK-Campus</li>\n</ul>\n<p>Ihr Profil</p>\n<ul>\n<li>Abgeschlossene Ausbildung zum Versicherungsfachmann, Versicherungskaufmann oder gleichwertige Ausbildung</li>\n<li>Bei Quereinsteigern: Abgeschlossene Berufsausbildung und Erfahrung im Verkauf (wir bilden Sie weiter zum Geprüften Versicherungsfachmann IHK)</li>\n<li>Ausgeprägte kommunikative Fähigkeiten und viel Freude am Umgang mit Menschen</li>\n<li>Organisierte und zielorientierte Arbeitsweise</li>\n<li>Ausdauer, Fleiß und Begeisterung für Ihre Kunden</li>\n</ul>\n<p>Detaillierte Informationen zu diesem Stellenangebot finden Sie auf unserer Homepage im Bereich Karriere im Außendienst. Nutzen Sie Ihre Karrierechancen! Ich freue mich auf Sie.</p>\n<p>Ihr/e Ansprechpartner/in\nOya Bektas\nDEVK Versicherungen\nHamburger Allee 22 u. 24\n30161 Hannover\nTel.: +49 175 2928310\nE-Mail: <a href="mailto:oya.bektas@vtp.devk.de">oya.bektas@vtp.devk.de</a></p>\n<p>Wir freuen uns darauf, Sie persönlich kennenzulernen. Falls Sie noch Fragen haben, rufen Sie uns gerne an.</p>\n',
#   'how_to_apply': '<p><a href="https://bewerbungsportal.devk.de/index">https://bewerbungsportal.devk.de/index</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBbzJlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--f2c5924d378178db1296d0fd2288741509979972/DEVK_logo_treffer.png'},
#  {'id': 'df27447e-d472-469d-9eed-ddea95338ca3',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/df27447e-d472-469d-9eed-ddea95338ca3',
#   'created_at': 'Sun Mar 28 19:31:47 UTC 2021',
#   'company': 'HIP Creative',
#   'company_url': 'https://hip.agency',
#   'location': 'Pensacola Florida',
#   'title': 'Full Stack Developer - (PHP/Javascript)',
#   'description': "<p>We are looking for a Full Stack Developer to produce scalable software solutions. You’ll be part of a cross-functional team that’s responsible for the full software development life cycle, from conception to deployment. As a Full Stack Developer, you should be comfortable around both front-end and back-end coding languages, development frameworks, and third-party libraries. You should also be a team player with a knack for visual design and utility.</p>\n<p>There are three aspects to our company that you could be working on.</p>\n<p>Marketing Agency - Wordpress websites - We have a team to convert the design files to Wordpress themes but we are looking to find ways to automate weekly updates and the development workflow.</p>\n<p>PracticeBeacon - This is the CRM we use for our clients. We build on top of GoHighlevel.com and want to focus on extending its capabilities by integrating into 3rd party APIs as well as build tools that look like they are apart of the application. This will be a major focus for 2021/2022.</p>\n<p>Internal Tools For Our Team - We have several internal tools we want to develop to help our team service our clients better. This could be anything from a better onboarding workflow, to building a system to analyze all our client's data to track their performance across marketing campaigns.</p>\n<p>Responsibilities:</p>\n<p>Work with the team to ideate software solutions\nDesign client-side and server-side architecture\nBuild the front-end of applications through appealing visual design\nDevelop and manage well-functioning databases and applications\nWrite effective APIs\nTest software to ensure responsiveness and efficiency\nTroubleshoot, debug and upgrade software\nCreate security and data protection settings\nBuild features and applications with a mobile responsive design\nWrite technical documentation</p>\n<p>Requirements:</p>\n<p>Proficient with Html/CSS/Javascript\nUnderstanding of GIT\nCreating and using docker or vagrant-based local development environments to troubleshoot issues and test solutions.\nProven experience as a Full Stack Developer or similar role\nExperience Developing Web Applications\nFamiliarity with common stacks\nKnowledge of multiple front-end languages and libraries (e.g. HTML/ CSS, JavaScript, XML, jQuery)\nKnowledge of multiple back-end languages (e.g. C#, Java, Python) and JavaScript frameworks (e.g. Vue, React, Node.js)\nFamiliarity with databases (e.g. MySQL, MongoDB), web servers (e.g. Apache) and UI/UX design\nExcellent communication and teamwork skills\nGreat attention to detail\nOrganizational skills\nAn analytical mind\nDegree in Computer Science, Statistics or relevant field</p>\n<p>Languages We Work With:</p>\n<p>PHP / Laravel</p>\n<p>ReactJS</p>\n<p>Bash</p>\n<p>Perl</p>\n<p>Javascript - VUE</p>\n",
#   'how_to_apply': '<p>Apply on linked in here: <a href="https://www.linkedin.com/jobs/view/2480420733/">https://www.linkedin.com/jobs/view/2480420733/</a></p>\n<p>or</p>\n<p>Email your resume to <a href="mailto:Justin@hipcreativeinc.com">Justin@hipcreativeinc.com</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBb2VlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--cb17df96398ebb224851fffd90d90b9c148f26a6/hip%20logo.png'}]

# %%
len(results)
# Out:
# 226
