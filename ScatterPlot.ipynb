# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df_real_estate = pd.read_csv("scatter_data.csv")
df_real_estate
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)      Price    Status
# 0            30      743.09  246.17268     Sold
# ...

# %%
plt.figure(figsize = (12, 8))
scatter = plt.scatter(df_real_estate['Area (ft.)'], df_real_estate["Price"], alpha = 0.6, c = df_real_estate['Building Type'], cmap = "viridis")
plt.legend(*scatter.legend_elements(), loc = "upper left", title = "Building type")
plt.title("relationship of area and price", fontsize = 14, weight = "bold")
plt.xlabel("Area", weight = "bold")
plt.ylabel("Price $")
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(df_real_estate["Area (ft.)"], df_real_estate['Price'], hue = df_real_estate['Building Type'], palette =["black", "darkblue", "purple", "pink", "white"], s =100)
plt.title("relationship of area and price", fontsize = 14, weight = "bold")
plt.xlabel("Area", weight = "bold")
plt.ylabel("Price $")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
