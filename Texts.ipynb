# %%
filename = "source.txt"

# %%
file = open(filename, "r")

# %%
text = file.read()

# %%
text
# Out:
# 'This is the simplest plain text file!\n'

# %%
file.close()

# %%
file.closed
# Out:
# True

# %% [markdown]
# Another way using with

# %%
with open(filename, "r") as out_file:
    old_text = out_file.read()

# %%
old_text
# Out:
# 'This is the simplest plain text file!\n'

# %%
with open(filename, "w") as out_file:
    out_file.write("This is new text")

# %%
with open(filename, "r") as out_file:
    new_text = out_file.read()
new_text
# Out:
# 'This is new text'

# %%
filename = "Lending-company-single-column-data.csv"

with open(filename, "r") as file:
    text = file.read()
text
# Out:
# '"LoanID,StringID,Product,CustomerGender,Location,Region,TotalPrice,StartDate,Deposit,DailyRate,TotalDays,AmountPaid30,AmountPaid60,AmountPaid360,LoanStatus360"\n"1,id_1,Product B,Male,Location 2,Region 2,16600,7/4/2014,2000,40,365,3121,4241,13621,Active"\n"2,id_2,Product B,Male,Location 3,,16600,1/2/2015,2000,40,365,3061,4171,15041,Active"\n"3,id_3,Product C,Female,Location 5,Region 5,15600,12/8/2012,1000,40,365,2160,3280,15340,"\n"4,id_4,Product B,Male,Location 6,Region 1,16600,,2000,40,365,3041,4241,15321,Active"\n"5,id_5,Product D,Female,Location 7,Region 2,20250,10/28/2013,2000,50,365,3470,4820,13720,Active"\n"6,id_6,Product B,Female,Location 10,Region 2,,4/19/2015,2000,40,365,3201,4141,14141,Active"\n"7,id_7,Product A,Male,Location 11,Region 3,20250,7/4/2016,2000,50,365,1851,3251,17701,Active"\n"8,id_8,Product B,Male,Location 12,Region 6,16600,4/24/2014,2000,40,365,3971,4131,15351,Active"\n"9,id_9,Product A,Female,Location 3,Region 3,22250,9/3/2015,4000,50,365,5750,7450,20250,"\n"10,id_10,Product A,Female,Location 13,Region 6,20250,7/25/2016,2000,50,365,1951,3251,17351,Active"\n"11,id_11,Product B,Female,Location 15,Region 2,16600,5/1/2014,2000,40,365,3160,4480,16380,Active"\n"12,id_12,Product D,Female,Location 16,Region 1,20250,3/29/2013,2000,50,365,3090,4190,10790,Active"\n"13,id_13,Product B,Male,Location 17,Region 3,16600,10/3/2014,2000,40,365,3121,5161,13441,Active"\n"14,id_14,Product A,Male,Location 19,Region 2,20750,9/18/2015,2500,50,365,1680,1680,5010,Active"\n"15,id_15,Product A,Female,Location 23,Region 4,22250,5/20/2015,4000,50,365,5500,6900,21000,Active"\n"16,id_16,Product B,Male,Location 27,Region 2,16600,5/31/2014,2000,40,365,3121,4801,15001,Active"\n"17,id_17,Product A,Male,Location 25,Region 3,22250,8/29/2015,4000,50,365,4000,4810,8010,Active"\n"18,id_18,Product B,Female,Location 26,Region 3,16600,6/6/2014,2000,40,365,3401,4201,15381,Active"\n"19,id_19,Product B,Male,Location 29,Region 1,16600,3/27/2015,2000,40,365,3128,4281,15781,Active"\n"20,id_20,Product E,Male,Location 30,Region 2,54625,10/11/2015,9000,125,365,12126,15251,45626,Active"\n"21,id_21,Product B,Male,Location 31,Region 4,16600,5/12/2014,2000,40,365,3560,4760,16200,Active"\n"22,id_22,Product A,Male,Location 17,Region 3,22250,7/7/2015,4000,50,365,6200,8400,21875,Active"\n"23,id_23,Product A,Male,Location 33,Region 3,19250,2/13/2016,1000,50,365,1400,2550,12700,Active"\n"24,id_24,Product C,NotSpecified,Location 34,Region 1,15600,12/21/2012,1000,40,365,2240,4560,14520,Active"\n"25,id_25,Product D,Female,Location 35,Region 6,20250,10/2/2013,2000,50,365,3551,4751,19101,Active"\n"26,id_26,Product A,Male,Location 37,Region 4,22250,9/11/2015,4000,50,365,6300,6600,14800,Active"\n"27,id_27,Product A,Female,Location 38,Region 3,19250,11/7/2015,1000,50,365,350,1750,7500,Active"\n"28,id_28,Product F,Female,Location 39,Region 6,69225,4/17/2016,9000,165,365,14501,16846,64001,Active"\n"29,id_29,Product D,Female,Location 40,Region 6,20250,12/14/2013,2000,50,365,5821,6821,15191,Active"\n"30,id_30,Product B,Male,Location 30,Region 2,16600,5/9/2015,2000,40,365,3641,4841,16311,Active"\n"31,id_31,Product B,Male,Location 41,Region 1,16600,2/24/2014,2000,40,365,3041,4231,16361,Active"\n"32,id_32,Product B,Male,Location 42,Region 4,16600,8/9/2014,2000,40,365,3430,4310,16024,Active"\n"33,id_33,Product A,Female,Location 22,Region 6,19250,3/7/2016,1000,50,365,-2870,-2870,1160,Active"\n"34,id_34,Product B,Male,Location 43,Region 3,16600,2/22/2014,2000,40,365,3600,4800,16400,Active"\n"35,id_35,Product A,Female,Location 46,Region 2,19250,2/8/2016,1000,50,365,250,850,5050,Active"\n"36,id_36,Product B,Female,Location 47,Region 7,16600,7/24/2014,2000,40,365,3121,3921,12721,Active"\n"37,id_37,Product B,Male,Location 50,Region 1,16600,3/24/2014,2000,40,365,2920,4200,15400,Active"\n"38,id_38,Product B,Male,Location 26,Region 3,16600,2/22/2015,2000,40,365,3041,3561,9081,Active"\n"39,id_39,Product C,NotSpecified,Location 52,Region 6,15600,9/13/2012,1000,40,365,2700,3500,11610,Acti ...

# %%
import pandas as pd

# %%
type(text)
# Out:
# str

# %%
pd.read_csv("Lending-company.csv")
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
#       TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0        17600.0  04/07/2018     2200         45          365       3221
# 1            NaN  02/01/2019     2200         45          365       3161
# 2        16600.0  08/12/2016     1000         45          365       2260
# 3        17600.0         NaN     2200         45          365       3141
# 4        21250.0  28/10/2017     2200         55          365       3570
# ...          ...         ...      ...        ...          ...        ...
# 1038     17300.0  29/12/2018     2200         45          365       3251
# 1039         NaN  28/03/2018     2200         45          365       4090
# 1040     17300.0  26/04/2018     2200         45          365       4051
# 1041     16300.0  25/10/2016     1000         45          365       1930
# 1042     17300.0  15/05/2019     2200         45          365       4451
#
#       AmtPaid60  AmtPaid360        LoanStatus
# 0          4166       14621            Active
# 1          4096       16041            Active
# 2          3205       16340               NaN
# 3          4166       16321            Active
# 4          4745       14720            Active
# ...         ...         ...               ...
# 1038       4743       16617  Finished Payment
# 1039       5582       16617  Finished Payment
# 1040       5143       16617  Finished Payment
# 1041       3462       15617  Finished Payment
# 1042       4743       16617  Finished Payment
#
# [1043 rows x 15 columns]

# %%
type(pd.read_csv("Lending-company.csv"))
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("Lending-company.csv", header=0)
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
#       TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0        17600.0  04/07/2018     2200         45          365       3221
# 1            NaN  02/01/2019     2200         45          365       3161
# 2        16600.0  08/12/2016     1000         45          365       2260
# 3        17600.0         NaN     2200         45          365       3141
# 4        21250.0  28/10/2017     2200         55          365       3570
# ...          ...         ...      ...        ...          ...        ...
# 1038     17300.0  29/12/2018     2200         45          365       3251
# 1039         NaN  28/03/2018     2200         45          365       4090
# 1040     17300.0  26/04/2018     2200         45          365       4051
# 1041     16300.0  25/10/2016     1000         45          365       1930
# 1042     17300.0  15/05/2019     2200         45          365       4451
#
#       AmtPaid60  AmtPaid360        LoanStatus
# 0          4166       14621            Active
# 1          4096       16041            Active
# 2          3205       16340               NaN
# 3          4166       16321            Active
# 4          4745       14720            Active
# ...         ...         ...               ...
# 1038       4743       16617  Finished Payment
# 1039       5582       16617  Finished Payment
# 1040       5143       16617  Finished Payment
# 1041       3462       15617  Finished Payment
# 1042       4743       16617  Finished Payment
#
# [1043 rows x 15 columns]

# %%
filename = "Lending-company.csv"
my_csv_data = pd.read_csv(filename)
my_csv_data
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
#       TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0        17600.0  04/07/2018     2200         45          365       3221
# 1            NaN  02/01/2019     2200         45          365       3161
# 2        16600.0  08/12/2016     1000         45          365       2260
# 3        17600.0         NaN     2200         45          365       3141
# 4        21250.0  28/10/2017     2200         55          365       3570
# ...          ...         ...      ...        ...          ...        ...
# 1038     17300.0  29/12/2018     2200         45          365       3251
# 1039         NaN  28/03/2018     2200         45          365       4090
# 1040     17300.0  26/04/2018     2200         45          365       4051
# 1041     16300.0  25/10/2016     1000         45          365       1930
# 1042     17300.0  15/05/2019     2200         45          365       4451
#
#       AmtPaid60  AmtPaid360        LoanStatus
# 0          4166       14621            Active
# 1          4096       16041            Active
# 2          3205       16340               NaN
# 3          4166       16321            Active
# 4          4745       14720            Active
# ...         ...         ...               ...
# 1038       4743       16617  Finished Payment
# 1039       5582       16617  Finished Payment
# 1040       5143       16617  Finished Payment
# 1041       3462       15617  Finished Payment
# 1042       4743       16617  Finished Payment
#
# [1043 rows x 15 columns]

# %%
type(my_csv_data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(my_csv_data)
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
#       TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0        17600.0  04/07/2018     2200         45          365       3221
# 1            NaN  02/01/2019     2200         45          365       3161
# 2        16600.0  08/12/2016     1000         45          365       2260
# 3        17600.0         NaN     2200         45          365       3141
# 4        21250.0  28/10/2017     2200         55          365       3570
# ...          ...         ...      ...        ...          ...        ...
# 1038     17300.0  29/12/2018     2200         45          365       3251
# 1039         NaN  28/03/2018     2200         45          365       4090
# 1040     17300.0  26/04/2018     2200         45          365       4051
# 1041     16300.0  25/10/2016     1000         45          365       1930
# 1042     17300.0  15/05/2019     2200         45          365       4451
#
#       AmtPaid60  AmtPaid360        LoanStatus
# 0          4166       14621            Active
# 1          4096       16041            Active
# 2          3205       16340               NaN
# 3          4166       16321            Active
# 4          4745       14720            Active
# ...         ...         ...               ...
# 1038       4743       16617  Finished Payment
# 1039       5582       16617  Finished Payment
# 1040       5143       16617  Finished Payment
# 1041       3462       15617  Finished Payment
# 1042       4743       16617  Finished Payment
#
# [1043 rows x 15 columns]

# %%
filename = "Lending-company.csv"
my_csv_data = pd.read_csv(filename, index_col='LoanID')
my_csv_data
# Out:
#            StringID    Product CustomerGender     Location    Region  \
# LoanID
# 1          LoanID_1  Product B         Female   Location 3  Region 2
# 2          LoanID_2  Product D         Female   Location 6  Region 6
# 3          LoanID_3  Product B           Male   Location 8  Region 3
# 4          LoanID_4  Product A           Male  Location 26  Region 2
# 5          LoanID_5  Product B         Female  Location 34  Region 3
# ...             ...        ...            ...          ...       ...
# 1039    LoanID_1039  Product B           Male  Location 73  Region 6
# 1040    LoanID_1040  Product A           Male  Location 82  Region 1
# 1041    LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1042    LoanID_1042  Product B         Female  Location 26  Region 6
# 1043    LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
#         TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# LoanID
# 1          17600.0  04/07/2018     2200         45          365       3221
# 2              NaN  02/01/2019     2200         45          365       3161
# 3          16600.0  08/12/2016     1000         45          365       2260
# 4          17600.0         NaN     2200         45          365       3141
# 5          21250.0  28/10/2017     2200         55          365       3570
# ...            ...         ...      ...        ...          ...        ...
# 1039       17300.0  29/12/2018     2200         45          365       3251
# 1040           NaN  28/03/2018     2200         45          365       4090
# 1041       17300.0  26/04/2018     2200         45          365       4051
# 1042       16300.0  25/10/2016     1000         45          365       1930
# 1043       17300.0  15/05/2019     2200         45          365       4451
#
#         AmtPaid60  AmtPaid360        LoanStatus
# LoanID
# 1            4166       14621            Active
# 2            4096       16041            Active
# 3            3205       16340               NaN
# 4            4166       16321            Active
# 5            4745       14720            Active
# ...           ...         ...               ...
# 1039         4743       16617  Finished Payment
# 1040         5582       16617  Finished Payment
# 1041         5143       16617  Finished Payment
# 1042         3462       15617  Finished Payment
# 1043         4743       16617  Finished Payment
#
# [1043 rows x 14 columns]

# %%
import numpy as np

# %%
lending_co_data_numeric_1 = np.loadtxt("Lending-Company-Numeric-Data.csv", delimiter=',')
lending_co_data_numeric_1
# Out:
# array([[ 2000.,    40.,   365.,  3121.,  4241., 13621.],
#        [ 2000.,    40.,   365.,  3061.,  4171., 15041.],
#        [ 1000.,    40.,   365.,  2160.,  3280., 15340.],
#        ...,
#        [ 2000.,    40.,   365.,  4201.,  5001., 16600.],
#        [ 1000.,    40.,   365.,  2080.,  3320., 15600.],
#        [ 2000.,    40.,   365.,  4601.,  4601., 16600.]])

# %%
lending_co_data_numeric_2 = np.genfromtxt("Lending-Company-Numeric-Data.csv", delimiter= ',')
lending_co_data_numeric_2
# Out:
# array([[ 2000.,    40.,   365.,  3121.,  4241., 13621.],
#        [ 2000.,    40.,   365.,  3061.,  4171., 15041.],
#        [ 1000.,    40.,   365.,  2160.,  3280., 15340.],
#        ...,
#        [ 2000.,    40.,   365.,  4201.,  5001., 16600.],
#        [ 1000.,    40.,   365.,  2080.,  3320., 15600.],
#        [ 2000.,    40.,   365.,  4601.,  4601., 16600.]])

# %%
np.array_equal(lending_co_data_numeric_1, lending_co_data_numeric_2)
# Out:
# True
